# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %%
# !pip install pypdf gradio
# Out:
# Requirement already satisfied: pypdf in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (6.10.2)
# Collecting gradio
#   Downloading gradio-6.13.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from gradio) (4.12.1)
# Collecting audioop-lts<=0.2.2 (from gradio)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp314-cp314-win_amd64.whl.metadata (6.3 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.136.0-py3-none-any.whl.metadata (28 kB)
# Collecting gradio-client==2.5.0 (from gradio)
#   Downloading gradio_client-2.5.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting hf-gradio<1.0,>=0.4.1 (from gradio)
#   Downloading hf_gradio-0.4.1-py3-none-any.whl.metadata (428 bytes)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub<2.0,>=0.33.5 (from gradio)
#   Downloading huggingface_hub-1.11.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jinja2<4.0 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from gradio) (3.0.2)
# Collecting numpy<3.0,>=1.0 (from gradio)
#   Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.8-cp314-cp314-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from gradio) (26.0)
# Collecting pandas<4.0,>=1.0 (from gradio)
#   Downloading pandas-3.0.2-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting pillow<13.0,>=8.0 (from gradio)
#   Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from gradio) (2.13.1)
# Collecting pydub<1.0 (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart<1.0,>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting pytz>=2017.2 (from gradio)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from gradio) (6.0.3)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<2.0,>=0.40.0 (from gradio)
#   Downloading starlette-1.0.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.15.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from gradio) (4.15.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.44.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting fsspec (from gradio-client==2.5.0->gradio)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna>=2.8 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Collecting tzdata (from pandas<4.0,>=1.0->gradio)
#   Downloading tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.1 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.1)
# Collecting click>=8.2.1 (from typer<1.0,>=0.12->gradio)
#   Downloading click-8.3.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: colorama in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from click>=8.2.1->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer<1.0,>=0.12->gradio)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\mayan\anaconda3\envs\AgenticAI\Lib\site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading gradio-6.13.0-py3-none-any.whl (19.7 MB)
#    ---------------------------------------- 0.0/19.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.7 MB 1.7 MB/s eta 0:00:12
#    -- ------------------------------------- 1.0/19.7 MB 1.8 MB/s eta 0:00:11
#    -- ------------------------------------- 1.3/19.7 MB 1.9 MB/s eta 0:00:10
#    --- ------------------------------------ 1.8/19.7 MB 1.9 MB/s eta 0:00:10
#    ---- ----------------------------------- 2.4/19.7 MB 2.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 2.6/19.7 MB 1.9 MB/s eta 0:00:09
#    ------ --------------------------------- 3.1/19.7 MB 2.0 MB/s eta 0:00:09
#    ------ --------------------------------- 3.4/19.7 MB 2.0 MB/s eta 0:00:09
#    ------- -------------------------------- 3.9/19.7 MB 2.0 MB/s eta 0:00:08
#    --------- ------------------------------ 4.5/19.7 MB 2.1 MB/s eta 0:00:08
#    ---------- ----------------------------- 5.0/19.7 MB 2.0 MB/s eta 0:00:08
#    ---------- ----------------------------- 5.0/19.7 MB 2.0 MB/s eta 0:00:08
#    ---------- ----------------------------- 5.2/19.7 MB 1.9 MB/s eta 0:00:08
#    ----------- ---------------------------- 5.8/19.7 MB 1.9 MB/s eta 0:00:08
#    ------------ --------------------------- 6.3/19.7 MB 1.9 MB/s eta 0:00:07
#    ------------- -------------------------- 6.8/19.7 MB 2.0 MB/s eta 0:00:07
#    -------------- ------------------------- 7.3/19.7 MB 2.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 8.1/19.7 MB 2.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 8.7/19.7 MB 2.1 MB/s eta 0:00:06
#    ------------------ --------------------- 9.2/19.7 MB 2.1 MB/s eta 0:00:05
#    ------------------- -------------------- 9.7/19.7 MB 2.2 MB/s eta 0:00:05
#    -------------------- ------------------- 10.2/19.7 MB 2.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 11.0/19.7 MB 2.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.5/19.7 MB 2.3 MB/s eta 0:00:04
#    ------------------------ --------------- 12.1/19.7 MB 2.3 MB/s eta 0:00:04
#    ------------------------- -------------- 12.6/19.7 MB 2.3 MB/s eta 0:00:04
#    -------------------------- ------------- 12.8/19.7 MB 2.3 MB/s eta 0:00:03
#    --------------------------- ------------ 13.6/19.7 MB 2.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 14.2/19.7 MB 2.3 MB/s eta 0:00:03
#    ------------------------------ --------- 14.9/19.7 MB 2.3 MB/s eta 0:00:03
#    ------------------------------- -------- 15.5/19.7 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 16.3/19.7 MB 2.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.8/19.7 MB 2.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 17.6/19.7 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 18.4/19.7 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 18.9/19.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 19.7/19.7 MB 2.4 MB/s  0:00:08
# Downloading gradio_client-2.5.0-py3-none-any.whl (59 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Downloading fastapi-0.136.0-py3-none-any.whl (117 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Downloading huggingface_hub-1.11.0-py3-none-any.whl (645 kB)
#    ---------------------------------------- 0.0/645.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/645.5 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/645.5 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/645.5 kB ? eta -:--:--
#    ---------------------------------------- 645.5/645.5 kB 792.2 kB/s  0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.7 MB 1.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.5/3.7 MB 1.3 MB/s eta 0:00:03
#    -------------- ------------------------- 1.3/3.7 MB 1.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.1/3.7 MB 2.3 MB/s eta 0:00:01
#    ------------------------------- -------- 2.9/3.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 3.4/3.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 2.5 MB/s  0:00:01
# Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.4 MB 1.5 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/12.4 MB 2.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/12.4 MB 1.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/12.4 MB 1.5 MB/s eta 0:00:08
#    ------- -------------------------------- 2.4/12.4 MB 1.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.1/12.4 MB 2.1 MB/s eta 0:00:05
#    ------------ --------------------------- 3.9/12.4 MB 2.3 MB/s eta 0:00:04
#    --------------- ------------------------ 4.7/12.4 MB 2.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.5/12.4 MB 2.6 MB/s eta 0:00:03
#    -------------------- ------------------- 6.3/12.4 MB 2.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.3/12.4 MB 2.9 MB/s eta 0:00:02
#    -------------------------- ------------- 8.1/12.4 MB 3.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.4 MB 3.1 MB/s eta 0:00:02
#    ------------------------------- -------- 9.7/12.4 MB 3.1 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.4 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.4 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.4 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 3.1 MB/s  0:00:04
# Downloading orjson-3.11.8-cp314-cp314-win_amd64.whl (127 kB)
# Downloading pandas-3.0.2-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 4.7 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.9 MB 4.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.9 MB 4.2 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.9 MB 4.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.9 MB 4.0 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.9 MB 4.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.9 MB 4.0 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.9 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.9 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.9 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 3.5 MB/s  0:00:02
# Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 3.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/7.2 MB 2.2 MB/s eta 0:00:03
#    -------- ------------------------------- 1.6/7.2 MB 2.8 MB/s eta 0:00:03
#    ------------- -------------------------- 2.4/7.2 MB 3.3 MB/s eta 0:00:02
#    --------------- ------------------------ 2.9/7.2 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 3.7/7.2 MB 3.2 MB/s eta 0:00:02
#    ------------------------ --------------- 4.5/7.2 MB 3.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.2 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 5.8/7.2 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 2.9 MB/s  0:00:02
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.26-py3-none-any.whl (28 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-1.0.0-py3-none-any.whl (72 kB)
# Downloading tomlkit-0.14.0-py3-none-any.whl (39 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading brotli-1.2.0-cp314-cp314-win_amd64.whl (375 kB)
# Downloading click-8.3.2-py3-none-any.whl (108 kB)
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading uvicorn-0.44.0-py3-none-any.whl (69 kB)
# Downloading tzdata-2026.1-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, pydub, brotli, tzdata, tomlkit, shellingham, semantic-version, python-multipart, pillow, orjson, numpy, mdurl, hf-xet, groovy, fsspec, filelock, click, audioop-lts, annotated-doc, uvicorn, starlette, pandas, markdown-it-py, safehttpx, rich, fastapi, typer, huggingface-hub, gradio-client, hf-gradio, gradio
#
#    ----------------------------------------  0/31 [pytz]
#    ----------------------------------------  0/31 [pytz]
#    ----------------------------------------  0/31 [pytz]
#    ----------------------------------------  0/31 [pytz]
#    - --------------------------------------  1/31 [pydub]
#    -- -------------------------------------  2/31 [brotli]
#    --- ------------------------------------  3/31 [tzdata]
#    --- ------------------------------------  3/31 [tzdata]
#    --- ------------------------------------  3/31 [tzdata]
#    --- ------------------------------------  3/31 [tzdata]
#    --- ------------------------------------  3/31 [tzdata]
#    ----- ----------------------------------  4/31 [tomlkit]
#    --------- ------------------------------  7/31 [python-multipart]
#    ---------- -----------------------------  8/31 [pillow]
#    ---------- -----------------------------  8/31 [pillow]
#    ---------- -----------------------------  8/31 [pillow]
#    ---------- -----------------------------  8/31 [pillow]
#    ---------- -----------------------------  8/31 [pillow]
#    ---------- -----------------------------  8/31 [pillow]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    ------------ --------------------------- 10/31 [numpy]
#    --------------- ------------------------ 12/31 [hf-xet]
#    ------------------ --------------------- 14/31 [fsspec]
#    ------------------ --------------------- 14/31 [fsspec]
#    ------------------ --------------------- 14/31 [fsspec]
#    ------------------ --------------------- 14/31 [fsspec]
#    ------------------- -------------------- 15/31 [filelock]
#    -------------------- ------------------- 16/31 [click]
#    ----------------------- ---------------- 18/31 [annotated-doc]
#    ------------------------ --------------- 19/31 [uvicorn]
#    ------------------------- -------------- 20/31 [starlette]
#    ------------------------- -------------- 20/31 [starlette]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    --------------------------- ------------ 21/31 [pandas]
#    ---------------------------- ----------- 22/31 [markdown-it-py]
#    ---------------------------- ----------- 22/31 [markdown-it-py]
#    ------------------------------ --------- 24/31 [rich]
#    ------------------------------ --------- 24/31 [rich]
#    ------------------------------ --------- 24/31 [rich]
#    ------------------------------ --------- 24/31 [rich]
#    ------------------------------ --------- 24/31 [rich]
#    ------------------------------ --------- 24/31 [rich]
#    -------------------------------- ------- 25/31 [fastapi]
#    -------------------------------- ------- 25/31 [fastapi]
#    --------------------------------- ------ 26/31 [typer]
#    ---------------------------------- ----- 27/31 [huggingface-hub]
#    ---------------------------------- ----- 27/31 [huggingface-hub]
#    ---------------------------------- ----- 27/31 [huggingface-hub]
#    ---------------------------------- ----- 27/31 [huggingface-hub]
#    ---------------------------------- ----- 27/31 [huggingface-hub]
#    ---------------------------------- ----- 27/31 [huggingface-hub]
#    ---------------------------------- ----- 27/31 [huggingface-hub]
#    ---------------------------------- ----- 27/31 [huggingface-hub]
#    ---------------------------------- ----- 27/31 [huggingface-hub]
#    ---------------------------------- ----- 27/31 [huggingface-hub]
#    ------------------------------------ --- 28/31 [gradio-client]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    -------------------------------------- - 30/31 [gradio]
#    ---------------------------------------- 31/31 [gradio]
#
# Successfully installed annotated-doc-0.0.4 audioop-lts-0.2.2 brotli-1.2.0 click-8.3.2 fastapi-0.136.0 filelock-3.29.0 fsspec-2026.3.0 gradio-6.13.0 gradio-client-2.5.0 groovy-0.1.2 hf-gradio-0.4.1 hf-xet-1.4.3 huggingface-hub-1.11.0 markdown-it-py-4.0.0 mdurl-0.1.2 numpy-2.4.4 orjson-3.11.8 pandas-3.0.2 pillow-12.2.0 pydub-0.25.1 python-multipart-0.0.26 pytz-2026.1.post1 rich-15.0.0 safehttpx-0.1.7 semantic-version-2.10.0 shellingham-1.5.4 starlette-1.0.0 tomlkit-0.14.0 typer-0.24.1 tzdata-2026.1 uvicorn-0.44.0

# %%
from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
# Out:
# True

# %%
reader = PdfReader("me/Profile.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# Noida
# mayankbtp108@gmail.com
# www.linkedin.com/in/
# mayank1008agarwal (LinkedIn)
# Top Skills
# PostgreSQL
# Web Development
# Java
# Certifications
# Java Full Stack
# Unity Beginner to Advance : Game
# Development
# Data structures and algorithmn
# HackXtreme
# Java Data Structures and Algorithm
# Masterclass
# Honors-Awards
# Selected as a Top-10 in Grand
# Finale
# Mayank Agarwal
# Gen AI & Backend Engineer | Designing scalable microservices
# (Spring Boot, Kotlin) | Passionate about AI systems & game
# development | Linux
# Noida, Uttar Pradesh, India
# Summary
# Hi, I'm Mayank Agarwal—a B.Tech CSE graduate and passionate
# full-stack developer currently working as an SDE Apprentice at S&P
# Global Inc.
# Skilled in building scalable microservices with Spring Boot, following
# clean architecture and REST and GraphQL principles. Proficient with
# Git for version control, efficient branching, and team collaboration to
# ensure smooth development workflows.
# Currently skilling myself in machine learning along with the
# integration in gaming engines to build something valuable to society.
# Let’s connect to share ideas, collaborate, or build something
# awesome!
# Experience
# S&P Global
# Software Developer Apprentice
# June 2025 - Present (11 months)
# Coding Pirates LPU
# Technical Team Member
# November 2022 - April 2023 (6 months)
# Phagwara, Punjab, India
# Education
# Lovely Professional University
# Bachelor of Technology - BTech, Computer science and engineering
#  · (2021 - 2025)
#   Page 1 of 2
# Allen Institute Kota
# Jee Mains, Entrance Exam ( IIT ) · (July 2019 - June 2021)
# Minarva Senior Secondary School
# Class XIIth, Mathematics and Computer Science · (July 2018 - June 2019)
# Arya Senior Secondary Public School
# Class Xth, Mathematics · (August 2016 - June 2017)
#   Page 2 of 2

# %%
import os
import requests

# %%
OLLAMA_BASE_URL = os.getenv("OLLAMA_BASE_URL")
OLLAMA_MODEL = os.getenv("OLLAMA_MODEL")

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Mayank Agarwal"

# %% [markdown]
# <h4>Now we are setting up here two diff prompts.One for the system and one for the user</h4>

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Mayank Agarwal. You are answering questions on Mayank Agarwal's website, particularly questions related to Mayank Agarwal's career, background, skills and experience. Your responsibility is to represent Mayank Agarwal for interactions on the website as faithfully as possible. You are given a summary of Mayank Agarwal's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Mayank Agarwal. I'm a software engineer. I'm originally from Bharatpur(Raj.).\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nNoida\nmayankbtp108@gmail.com\nwww.linkedin.com/in/\nmayank1008agarwal (LinkedIn)\nTop Skills\nPostgreSQL\nWeb Development\nJava\nCertifications\nJava Full Stack\nUnity Beginner to Advance : Game\nDevelopment\nData structures and algorithmn\nHackXtreme\nJava Data Structures and Algorithm\nMasterclass\nHonors-Awards\nSelected as a Top-10 in Grand\nFinale\nMayank Agarwal\nGen AI & Backend Engineer | Designing scalable microservices\n(Spring Boot, Kotlin) | Passionate about AI systems & game\ndevelopment | Linux\nNoida, Uttar Pradesh, India\nSummary\nHi, I'm Mayank Agarwal—a B.Tech CSE graduate and passionate\nfull-stack developer currently working as an SDE Apprentice at S&P\nGlobal Inc.\nSkilled in building scalable microservices with Spring Boot, following\nclean architecture and REST and GraphQL principles. Proficient with\nGit for version control, efficient branching, and team collaboration to\nensure smooth development workflows.\nCurrently skilling myself in machine learning along with the\nintegration in gaming engines to build something valuable to society.\nLet’s connect to share ideas, collaborate, or build something\nawesome!\nExperience\nS&P Global\nSoftware Developer Apprentice\nJune 2025\xa0-\xa0Present\xa0(11 months)\nCoding Pirates LPU\nTechnical Team Member\nNovember 2022\xa0-\xa0April 2023\xa0(6 months)\nPhagwara, Punjab, India\nEducation\nLovely Professional University\nBachelor of Technology - BTech,\xa0Computer science and engineering\n\xa0·\xa0(2021\xa0-\xa02025)\n\xa0 Page 1 of 2\xa0 \xa0\nAllen Institute Kota \nJee Mains,\xa0Entrance Exam ( IIT )\xa0·\xa0(July 2019\xa0-\xa0June 2021)\nMinarva Senior Secondary School \nClass XIIth,\xa0Mathematics and Computer Science\xa0·\xa0(July 2018\xa0-\xa0June 2019)\nArya Senior Secondary Public School\nClass Xth,\xa0Mathematics\xa0·\xa0(August 2016\xa0-\xa0June 2017)\n\xa0 Page 2 of 2\n\nWith this context, please chat with the user, always staying in character as Mayank Agarwal."

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = requests.post(
        f"{OLLAMA_BASE_URL}/api/chat",
        json={
            "model":OLLAMA_MODEL,
            "messages":messages,
            "stream": False
        }
    )
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply

# %%
evaluate(reply, "do you hold a patent?", messages[:1])

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
